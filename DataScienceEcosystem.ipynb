# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem #

# %% [markdown]
# In this notebook, we summarize the foundational Data Science Tools and Ecosystem . We begin by exploring the primary programming languages used by data scientists, such as Python and R, and then review the essential libraries, packages, and tools that form the backbone of modern data science projects, including well-known examples like Pandas, NumPy, and Scikit-learn. Finally, we will touch upon the integrated environments like Jupyter Notebooks and JupyterLab that facilitate an interactive, code-and-narrative approach to data analysis and machine learning.

# %% [markdown]
# **Objectives:**
# * List popular languages used in Data Science
# * List popular libraries used in Data Science
# * List enviroments to work in Data Science
# * Show examples of arithemtic problems in Jupyter Notebook

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the most used libraries used by Data Scientists include:
# 1. Pandas (Python: Data manipulation)
# 2. NumPy (Python: Numerical computing)
# 3. Dplyr (R: Data manipulation)
# 4. ggplot (R: Data visualization)

# %% [markdown]
# |Data Science Tools|
# |------|
# |Jupyter Notebooks|
# |RStudio|
# |JupyterLab|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python. ###

# %%
# This is a simple arithmetic expression to multiply the add integers.

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author ##
# Matías Oyaneder
